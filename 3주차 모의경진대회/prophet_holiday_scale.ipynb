# %%
#!pip install pandas
#!pip install numpy
# Out:
# Collecting pandas
#   Downloading pandas-1.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      |████████████████████████████████| 11.7 MB 14.3 MB/s eta 0:00:01    |█▌                              | 542 kB 14.3 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10" in /opt/conda/lib/python3.8/site-packages (from pandas) (1.19.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.8/site-packages (from pandas) (2020.5)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.15.0)
# Installing collected packages: pandas
# Successfully installed pandas-1.4.1
# Requirement already satisfied: numpy in /opt/conda/lib/python3.8/site-packages (1.19.2)
# ERROR: unknown command "torch"

# %%
# 라이브러리 임포트
import os
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch import autograd 
from torch.utils import data
from torch.optim import Adam
from torchvision import datasets, transforms
import torchvision.models as models

# %% [markdown]
# ## prophet

# %%
DATASET_PATH = os.path.join('./traffic/data')

# %%
df_train = pd.read_csv(os.path.join(DATASET_PATH, 'train.csv'))
df_train
# Out:
#             날짜  시간      10     100    101    120    121   140     150   160  \
# 0     20200101   0   83247   19128   2611   5161   1588   892   32263  1636
# 1     20200101   1   89309   19027   3337   5502   1650  1043   35609  1644
# 2     20200101   2   66611   14710   2970   4631   1044   921   26821  1104
# 3     20200101   3   53290   13753   2270   4242   1021   790   21322   909
# 4     20200101   4   52095   17615   2406   3689   1840   922   22711  1354
# ...        ...  ..     ...     ...    ...    ...    ...   ...     ...   ...
# 3274  20200517  19  311727  101285  10085  30637  10060  8749  148935  6801
# 3275  20200517  20  305354   91426   8607  26021   8095  7198  136503  6147
# 3276  20200517  21  306008   75113   6325  19933   5711  4494  129412  5134
# 3277  20200517  22  237447   49498   4209  12145   3891  2718   96698  3526
# 3278  20200517  23  150312   27410   2350   6406   1803  1614   55788  1849
#
#       ...  1020   1040   1100   1200  1510   2510  3000   4510   5510   6000
# 0     ...  1311   3482  11299   7072  1176   3810   748   3920   2133   3799
# 1     ...  1162   3849  13180   8771  1283   3763   782   3483   2057   4010
# 2     ...   768   2299   7986   5426  1536   3229   491   2634   1526   3388
# 3     ...   632   1716   5703   3156  1104   2882   431   2488   1268   3686
# 4     ...   875   2421   5816   2933  1206   2433   499   2952   1927   5608
# ...   ...   ...    ...    ...    ...   ...    ...   ...    ...    ...    ...
# 3274  ...  6726  15431  25597  14292  9300  22238  3786  16936  10729  20194
# 3275  ...  5501  15378  24661  14747  8239  20604  3203  15018   9767  17962
# 3276  ...  4216  12558  22781  14081  6392  17937  2447  12403   7825  14031
# 3277  ...  2578   8870  16640  11066  4427  11955  1495   7507   5387   8889
# 3278  ...  1377   5021  10058   7139  2250   6844   735   4116   3046   4606
#
# [3279 rows x 37 columns]

# %%
# # len(df_train.columns[3:])
# drop_list = []
# for i in df_train.columns[3:]:
#     # drop_list.append(df_train.columns[]
#     drop_list.append(i)

# df_train = df_train.drop(columns=drop_list)
df_train['날짜'] = df_train['날짜'].astype('str')
df_train['시간'] = df_train['시간'].astype('str')
df_train['날짜'] = df_train['날짜'] + ' ' + df_train['시간']

# %%
df_train
# Out:
#                날짜  시간      10     100    101    120    121   140     150  \
# 0      20200101 0   0   83247   19128   2611   5161   1588   892   32263
# 1      20200101 1   1   89309   19027   3337   5502   1650  1043   35609
# 2      20200101 2   2   66611   14710   2970   4631   1044   921   26821
# 3      20200101 3   3   53290   13753   2270   4242   1021   790   21322
# 4      20200101 4   4   52095   17615   2406   3689   1840   922   22711
# ...           ...  ..     ...     ...    ...    ...    ...   ...     ...
# 3274  20200517 19  19  311727  101285  10085  30637  10060  8749  148935
# 3275  20200517 20  20  305354   91426   8607  26021   8095  7198  136503
# 3276  20200517 21  21  306008   75113   6325  19933   5711  4494  129412
# 3277  20200517 22  22  237447   49498   4209  12145   3891  2718   96698
# 3278  20200517 23  23  150312   27410   2350   6406   1803  1614   55788
#
#        160  ...  1020   1040   1100   1200  1510   2510  3000   4510   5510  \
# 0     1636  ...  1311   3482  11299   7072  1176   3810   748   3920   2133
# 1     1644  ...  1162   3849  13180   8771  1283   3763   782   3483   2057
# 2     1104  ...   768   2299   7986   5426  1536   3229   491   2634   1526
# 3      909  ...   632   1716   5703   3156  1104   2882   431   2488   1268
# 4     1354  ...   875   2421   5816   2933  1206   2433   499   2952   1927
# ...    ...  ...   ...    ...    ...    ...   ...    ...   ...    ...    ...
# 3274  6801  ...  6726  15431  25597  14292  9300  22238  3786  16936  10729
# 3275  6147  ...  5501  15378  24661  14747  8239  20604  3203  15018   9767
# 3276  5134  ...  4216  12558  22781  14081  6392  17937  2447  12403   7825
# 3277  3526  ...  2578   8870  16640  11066  4427  11955  1495   7507   5387
# 3278  1849  ...  1377   5021  10058   7139  2250   6844   735   4116   3046
#
#        6000
# 0      3799
# 1      4010
# 2      3388
# 3      3686
# 4      5608
# ...     ...
# 3274  20194
# 3275  17962
# 3276  14031
# 3277   8889
# 3278   4606
#
# [3279 rows x 37 columns]

# %%
for i in range(len(df_train)):
    if len(df_train['시간'][i]) == 1:
        df_train['날짜'][i] = df_train['날짜'][i][0:4] + '-' + df_train['날짜'][i][4:6] + '-' + df_train['날짜'][i][6:8] + ' 0' + df_train['날짜'][i][9:10] + ':00:00'
    else:
        df_train['날짜'][i] = df_train['날짜'][i][0:4] + '-' + df_train['날짜'][i][4:6] + '-' + df_train['날짜'][i][6:8] + ' ' + df_train['날짜'][i][9:11] + ':00:00'

df_train['날짜'] = pd.to_datetime(df_train['날짜'])
df_train
# Out:
# /tmp/ipykernel_7514/767065649.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['날짜'][i] = df_train['날짜'][i][0:4] + '-' + df_train['날짜'][i][4:6] + '-' + df_train['날짜'][i][6:8] + ' 0' + df_train['날짜'][i][9:10] + ':00:00'
# /tmp/ipykernel_7514/767065649.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['날짜'][i] = df_train['날짜'][i][0:4] + '-' + df_train['날짜'][i][4:6] + '-' + df_train['날짜'][i][6:8] + ' ' + df_train['날짜'][i][9:11] + ':00:00'
#                       날짜  시간      10     100    101    120    121   140  \
# 0    2020-01-01 00:00:00   0   83247   19128   2611   5161   1588   892
# 1    2020-01-01 01:00:00   1   89309   19027   3337   5502   1650  1043
# 2    2020-01-01 02:00:00   2   66611   14710   2970   4631   1044   921
# 3    2020-01-01 03:00:00   3   53290   13753   2270   4242   1021   790
# 4    2020-01-01 04:00:00   4   52095   17615   2406   3689   1840   922
# ...                  ...  ..     ...     ...    ...    ...    ...   ...
# 3274 2020-05-17 19:00:00  19  311727  101285  10085  30637  10060  8749
# 3275 2020-05-17 20:00:00  20  305354   91426   8607  26021   8095  7198
# 3276 2020-05-17 21:00:00  21  306008   75113   6325  19933   5711  4494
# 3277 2020-05-17 22:00:00  22  237447   49498   4209  12145   3891  2718
# 3278 2020-05-17 23:00:00  23  150312   27410   2350   6406   1803  1614
#
#          150   160  ...  1020   1040   1100   1200  1510   2510  3000   4510  \
# 0      32263  1636  ...  1311   3482  11299   7072  1176   3810   748   3920
# 1      35609  1644  ...  1162   3849  13180   8771  1283   3763   782   3483
# 2      26821  1104  ...   768   2299   7986   5426  1536   3229   491   2634
# 3      21322   909  ...   632   1716   5703   3156  1104   2882   431   2488
# 4      22711  1354  ...   875   2421   5816   2933  1206   2433   499   2952
# ...      ...   ...  ...   ...    ...    ...    ...   ...    ...   ...    ...
# 3274  148935  6801  ...  6726  15431  25597  14292  9300  22238  3786  16936
# 3275  136503  6147  ...  5501  15378  24661  14747  8239  20604  3203  15018
# 3276  129412  5134  ...  4216  12558  22781  14081  6392  17937  2447  12403
# 3277   96698  3526  ...  2578   8870  16640  11066  4427  11955  1495   7507
# 3278   55788  1849  ...  1377   5021  10058   7139  2250   6844   735   4116
#
#        5510   6000
# 0      2133   3799
# 1      2057   4010
# 2      1526   3388
# 3      1268   3686
# 4      1927   5608
# ...     ...    ...
# 3274  10729  20194
# 3275   9767  17962
# 3276   7825  14031
# 3277   5387   8889
# 3278   3046   4606
#
# [3279 rows x 37 columns]

# %%
df_train.dtypes
# Out:
# 날짜      datetime64[ns]
# 시간              object
# 10               int64
# 100              int64
# 101              int64
# 120              int64
# 121              int64
# 140              int64
# 150              int64
# 160              int64
# 200              int64
# 201              int64
# 251              int64
# 270              int64
# 300              int64
# 301              int64
# 351              int64
# 352              int64
# 370              int64
# 400              int64
# 450              int64
# 500              int64
# 550              int64
# 600              int64
# 650              int64
# 652              int64
# 1000             int64
# 1020             int64
# 1040             int64
# 1100             int64
# 1200             int64
# 1510             int64
# 2510             int64
# 3000             int64
# 4510             int64
# 5510             int64
# 6000             int64
# dtype: object

# %%
df_train = df_train.drop(columns='시간')
df_train
# Out:
#                       날짜      10     100    101    120    121   140     150  \
# 0    2020-01-01 00:00:00   83247   19128   2611   5161   1588   892   32263
# 1    2020-01-01 01:00:00   89309   19027   3337   5502   1650  1043   35609
# 2    2020-01-01 02:00:00   66611   14710   2970   4631   1044   921   26821
# 3    2020-01-01 03:00:00   53290   13753   2270   4242   1021   790   21322
# 4    2020-01-01 04:00:00   52095   17615   2406   3689   1840   922   22711
# ...                  ...     ...     ...    ...    ...    ...   ...     ...
# 3274 2020-05-17 19:00:00  311727  101285  10085  30637  10060  8749  148935
# 3275 2020-05-17 20:00:00  305354   91426   8607  26021   8095  7198  136503
# 3276 2020-05-17 21:00:00  306008   75113   6325  19933   5711  4494  129412
# 3277 2020-05-17 22:00:00  237447   49498   4209  12145   3891  2718   96698
# 3278 2020-05-17 23:00:00  150312   27410   2350   6406   1803  1614   55788
#
#        160    200  ...  1020   1040   1100   1200  1510   2510  3000   4510  \
# 0     1636   7938  ...  1311   3482  11299   7072  1176   3810   748   3920
# 1     1644   9896  ...  1162   3849  13180   8771  1283   3763   782   3483
# 2     1104   9343  ...   768   2299   7986   5426  1536   3229   491   2634
# 3      909  10009  ...   632   1716   5703   3156  1104   2882   431   2488
# 4     1354  15497  ...   875   2421   5816   2933  1206   2433   499   2952
# ...    ...    ...  ...   ...    ...    ...    ...   ...    ...   ...    ...
# 3274  6801  26101  ...  6726  15431  25597  14292  9300  22238  3786  16936
# 3275  6147  20759  ...  5501  15378  24661  14747  8239  20604  3203  15018
# 3276  5134  14496  ...  4216  12558  22781  14081  6392  17937  2447  12403
# 3277  3526   9363  ...  2578   8870  16640  11066  4427  11955  1495   7507
# 3278  1849   5722  ...  1377   5021  10058   7139  2250   6844   735   4116
#
#        5510   6000
# 0      2133   3799
# 1      2057   4010
# 2      1526   3388
# 3      1268   3686
# 4      1927   5608
# ...     ...    ...
# 3274  10729  20194
# 3275   9767  17962
# 3276   7825  14031
# 3277   5387   8889
# 3278   3046   4606
#
# [3279 rows x 36 columns]

# %%
# !pip install fbprophet==0.7.1

# %%
#!pip install pystan==2.19.1.1
#!pip install fbprophet==0.7.1
#!pip install prophet==1.0.1
from prophet import Prophet

# %%
# !pip install datetime
# Out:
# Collecting datetime
#   Downloading DateTime-4.4-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 803 kB/s  eta 0:00:01
# Requirement already satisfied: pytz in /opt/conda/lib/python3.8/site-packages (from datetime) (2020.5)
# Collecting zope.interface
#   Downloading zope.interface-5.4.0-cp38-cp38-manylinux2010_x86_64.whl (259 kB)
#      |████████████████████████████████| 259 kB 17.4 MB/s eta 0:00:01
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from zope.interface->datetime) (50.3.1.post20201107)
# Installing collected packages: zope.interface, datetime
# Successfully installed datetime-4.4 zope.interface-5.4.0

# %%
# !pip install holidays
import holidays
from datetime import date
import pandas as pandas

kr_holidays = holidays.KR()
# kr_holidays = holidays.country_holidays('KR')

print(date(2020, 1, 1) in kr_holidays) # 원하는 년도 불러오기 
kr_holidays

for d, name in iter(kr_holidays.items()): # 딕셔너리 확인하기
    print(d, name)
# Out:
# True
# 2020-01-01 New Year's Day
# 2020-01-24 The day preceding of Lunar New Year's Day
# 2020-01-25 Lunar New Year's Day
# 2020-01-26 The second day of Lunar New Year's Day
# 2020-01-27 Alternative holiday of Lunar New Year's Day
# 2020-03-01 Independence Movement Day
# 2020-04-30 Birthday of the Buddha
# 2020-05-05 Children's Day
# 2020-05-01 Labour Day
# 2020-06-06 Memorial Day
# 2020-08-15 Liberation Day
# 2020-09-30 The day preceding of Chuseok
# 2020-10-01 Chuseok
# 2020-10-02 The second day of Chuseok
# 2020-10-03 National Foundation Day
# 2020-10-09 Hangeul Day
# 2020-12-25 Christmas Day
# 2020-08-17 Alternative public holiday

# %%
holidays_list =kr_holidays.values()
ds_list = kr_holidays.keys()

print(holidays_list)
print(ds_list)
# Out:
# dict_values(["New Year's Day", "The day preceding of Lunar New Year's Day", "Lunar New Year's Day", "The second day of Lunar New Year's Day", "Alternative holiday of Lunar New Year's Day", 'Independence Movement Day', 'Birthday of the Buddha', "Children's Day", 'Labour Day', 'Memorial Day', 'Liberation Day', 'The day preceding of Chuseok', 'Chuseok', 'The second day of Chuseok', 'National Foundation Day', 'Hangeul Day', 'Christmas Day', 'Alternative public holiday'])
# dict_keys([datetime.date(2020, 1, 1), datetime.date(2020, 1, 24), datetime.date(2020, 1, 25), datetime.date(2020, 1, 26), datetime.date(2020, 1, 27), datetime.date(2020, 3, 1), datetime.date(2020, 4, 30), datetime.date(2020, 5, 5), datetime.date(2020, 5, 1), datetime.date(2020, 6, 6), datetime.date(2020, 8, 15), datetime.date(2020, 9, 30), datetime.date(2020, 10, 1), datetime.date(2020, 10, 2), datetime.date(2020, 10, 3), datetime.date(2020, 10, 9), datetime.date(2020, 12, 25), datetime.date(2020, 8, 17)])

# %%
holidays_df = pd.DataFrame(columns=['ds','holiday'])
holidays_df['ds'] = ds_list
holidays_df['holiday'] = holidays_list

# %%
# holiday_df 확인하기
holidays_df
# Out:
#             ds                                      holiday
# 0   2020-01-01                               New Year's Day
# 1   2020-01-24    The day preceding of Lunar New Year's Day
# 2   2020-01-25                         Lunar New Year's Day
# 3   2020-01-26       The second day of Lunar New Year's Day
# 4   2020-01-27  Alternative holiday of Lunar New Year's Day
# 5   2020-03-01                    Independence Movement Day
# 6   2020-04-30                       Birthday of the Buddha
# 7   2020-05-05                               Children's Day
# 8   2020-05-01                                   Labour Day
# 9   2020-06-06                                 Memorial Day
# 10  2020-08-15                               Liberation Day
# 11  2020-09-30                 The day preceding of Chuseok
# 12  2020-10-01                                      Chuseok
# 13  2020-10-02                    The second day of Chuseok
# 14  2020-10-03                      National Foundation Day
# 15  2020-10-09                                  Hangeul Day
# 16  2020-12-25                                Christmas Day
# 17  2020-08-17                   Alternative public holiday

# %%
# df_train.columns[0:5]
#  if df['mths_since_last_delinq{}'.format(i+1)][j] == 1:

submission_file_path = os.path.join(DATASET_PATH, 'sample_submission.csv')
submission_table = pd.read_csv(submission_file_path)
submission_table

for i, col in enumerate(df_train.columns[1:]):

    df_for = df_train[['날짜', '{}'.format(col)]]
    df_for.columns = ['ds', 'y']
    
    # default =10
    m = Prophet(weekly_seasonality = 30,
               holidays = holidays_df,
               holidays_prior_scale = 20)
# m.add_seasonality(name='monthly', period=30.5, fourier_order=5
    m.fit(df_for)
    
    
    future=m.make_future_dataframe(periods=24*14 , freq='H')  # 14일치를 예측할 것.
    forecast=m.predict(future)
    df_pred = forecast[['ds', 'yhat']][3447:].reset_index()
    
    submission_table['{}'.format(col)] = df_pred["yhat"]

submission_table
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /opt/conda/lib/python3.8/site-packages/prophet/forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# Initial log joint probability = -141.231
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       7113.71    0.00838965       435.087      0.2733      0.2733      120
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       
# 167  3099.515226  3165.750078   68481.742958  2580.481375   8852.802942  ...
#
#             1020          1040          1100          1200         1510  \
# 0    2038.013455   4546.139187  10556.503989   4871.153719  3940.676778
# 1    1626.939232   3306.649485   7049.474096   2625.424271  3423.341839
# 2    1154.728675   2396.703266   4369.471001    952.155228  3252.153056
# 3    1013.529684   2594.453955   5243.661718   1154.645341  3366.232594
# 4    1618.704102   4558.278764  11489.120973   4108.064195  3607.069821
# ..           ...           ...           ...           ...          ...
# 163  7483.853526  14871.962340  36965.162362  17151.093175  8959.219177
# 164  5427.307202  12394.680564  30020.687353  14649.534863  7664.511226
# 165  3806.263680   9783.089069  22906.853391  11740.665304  6645.234751
# 166  2879.422126   7619.051554  17588.576771   9148.012174  5791.187006
# 167  2479.131785   6041.286308  14095.351777   6985.129266  4973.590586
#
#              2510         3000          4510          5510          6000
# 0     8290.998067   798.131178   3451.656398   3148.897906   5055.695403
# 1     7039.479761   681.010143   2717.880762   2490.907851   3964.646598
# 2     6180.759786   402.304121   1552.146673   1779.929697   2920.794713
# 3     6171.700670   214.969991   1197.383627   1725.203748   3041.021616
# 4     7450.018802   455.060975   3100.817207   2956.153476   5241.118776
# ..            ...          ...           ...           ...           ...
# 163  23065.324000  3497.023199  16040.520075  10812.351636  19280.169308
# 164  18622.903048  2431.624010  11662.055937   8005.747211  14092.991749
# 165  14855.705136  1468.322620   7520.103439   5663.355788   9805.404952
# 166  12151.159162   903.925770   4909.344804   4297.220771   7272.250402
# 167  10287.400982   750.976447   3956.352388   3721.849481   6137.048309
#
# [168 rows x 36 columns]

# %% [raw]
# submission_file_path = os.path.join(DATASET_PATH, 'sample_submission.csv')
# submission_table = pd.read_csv(submission_file_path)
# submission_table

# %% [raw]
# submission_table.to_csv('prediction.csv', index=False)

# %% [raw]
# # for문 코드를 위한 사전시도 (skip)

# %% [raw]
# # 날짜와 도로 1개를 남기고 ds와 y로 바꾸기
#
# # len(df_train.columns[2:])
# drop_list = []
# for i in df_train.columns[2:]:
#     # drop_list.append(df_train.columns[]
#     drop_list.append(i)
#
# df_train = df_train.drop(drop_list, axis = 1)
# df_train.columns = ['ds', 'y']
#
# df_train

# %% [raw]
# prophet

# %% [raw]
# # !pip install pystan==2.19.1.1
# # !pip install fbprophet==0.7.1
# # !pip install prophet==1.0.1
# from prophet import Prophet

# %% [raw]
# # prophet 학습
#
# m = Prophet(yearly_seasonality=True)
# m.fit(df_train)

# %% [raw]
# future=m.make_future_dataframe(periods=24*14 , freq='H')  # 14일치를 예측할 것.
# forecast=m.predict(future)

# %% [raw]
# df_pred = forecast[['ds', 'yhat']][3447:].reset_index()

# %% [raw]
# forecast['yhat']

# %% [raw]
# df_pred['yhat']

# %% [raw]
# submission_file_path = os.path.join(DATASET_PATH, 'sample_submission.csv')
# submission_table = pd.read_csv(submission_file_path)
# submission_table

# %% [raw]
# submission_table['10'] = df_pred["yhat"]
# submission_table
